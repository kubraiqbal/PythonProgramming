# %%
# Name - Kubra Iqbal
# Honor Statement : I have not given or received any unauthorized assistance on this assignment.
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
# %matplotlib inline
import pandas as pd 
import os,sys
from scipy import stats

# %%
fname = "/Users/kubraiqbal/Desktop/housing.csv"
housing = np.loadtxt(fname, delimiter=',',dtype=str)
print (housing)
# Out:
# [['longitude' 'latitude' 'housing_median_age' ... 'median_income'
#   'median_house_value' 'ocean_proximity']
#  ['-122.23' '37.88' '41.0' ... '8.3252' '452600.0' 'NEAR BAY']
#  ['-122.22' '37.86' '21.0' ... '8.3014' '358500.0' 'NEAR BAY']
#  ...
#  ['-121.22' '39.43' '17.0' ... '1.7' '92300.0' 'INLAND']
#  ['-121.32' '39.43' '18.0' ... '1.8672' '84700.0' 'INLAND']
#  ['-121.24' '39.37' '16.0' ... '2.3886' '89400.0' 'INLAND']]

# %%
#Size of the housing dataset
housing.size
# Out:
# 206410

# %%
#to run the data type
housing.dtype
# Out:
# dtype('<U18')

# %%
#to find the dimensions of the housing dataset
housing.shape
# Out:
# (20641, 10)

# %%
# Define the price column - for hist
price = housing[:, -1]

# %%
# Define the population column - hist
population, age = housing[:, [5, 8]].T

# %%
#Run
population = housing[1:,5] 
plotting = population.astype(float) 
plt.hist(plotting,bins=300)
plt.axis([0,10000,0,3500])
plt.xlabel('population')
plt.ylabel('getthecount')
# Out:
# Text(0,0.5,'getthecount')

# %%
ocean_proximity =  housing[1:,9]
dict = {}
count = 0
for i in ocean_proximity: 
    if i in dict:
        dict[i] += 1
    else:
        dict[i] = 1
names = list(dict.keys()) 
countsofvalues = list(dict.values()) 
plt.bar(names,countsofvalues)
# Out:
# <BarContainer object of 5 artists>

# %%
age = housing[1:,2] 
age_xaxis = age.astype(float)
population = housing[1:,5]
population_yaxis = population.astype(float)
price_color = housing[1:,-2]
plt.scatter(age_xaxis,population_yaxis,c = price_color)
plt.xlabel('Age')
plt.ylabel('populationulation')
plt.axis([0, 50, 0, 40000])
# Out:
# [0, 50, 0, 40000]

# %%
# The above scatterplot shows a scatterplot between the popluation and the age. It shows that that the scatterplot

# %%
#is not that spread out. All the points are very low except a few points that are on the top and pretty high.

# %%
#Generally, most of the points are clustered together and there are a few outliers
